# %%
import pandas as pd
import numpy as np
import random
import string
from pathlib import Path

# %%
excel_dir = Path('./test_file')
excel_files = excel_dir.glob('*.xlsx')
all_df = []
for i in excel_files:
    df = pd.read_excel(i)
    all_df.append(df)
    print(df)
all_df = pd.concat(all_df)
all_df
# Out:
#        日期    客户   品名    价格    单位      总金额
# 0   44562   客户1   苹果  3.90   2.0    7.800
# 1   44563   客户2   梨子  2.90   5.0   14.500
# 2   44564   客户3   香蕉  4.60  15.0   69.000
# 3   44565   客户1   橙子  6.60  15.0   99.000
# 4   44566   客户2   柚子  5.90   2.0   11.800
# 5   44567   客户3   西瓜  6.90   3.0   20.700
# 6   44568   客户1  哈密瓜  7.90   9.0   71.100
# 7   44569   客户2   瓜子  2.90  16.0   46.400
# 8   44570   客户3  草莓   9.90  15.0  148.500
# 9   44571   客户1   橙子  6.60  22.0  145.200
# 10  44572   客户2   柚子  6.80  22.0  149.600
# 11  44573   客户3   西瓜  3.60  32.0  115.200
# 12  44574   客户1  哈密瓜  5.45  15.0   81.750
# 13  44575   客户2   瓜子  5.28  17.0   89.760
# 14  44576   客户3  草莓   5.11  15.0   76.650
# 15  44577   客户4   橙子  4.94  16.0   79.040
# 16  44578   客户5   柚子  4.77  13.0   62.010
# 17  44579   客户6   西瓜  4.60  19.0   87.400
# 18  44580   客户7  哈密瓜  4.43  22.0   97.460
# 19  44581   客户8   瓜子  4.26  28.0  119.280
# 20  44582   客户9  草莓   4.09  24.0   98.160
# ...
